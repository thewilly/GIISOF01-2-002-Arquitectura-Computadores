# %% [markdown]
# # Comparación programas con variable o con overload.

# %% [markdown]
# ## Programa con variables

# %% [markdown]
# **Tamaño:** 1225240
# **Tiempo individual:** 4.777012 / 80 -> 0,059713

# %% [markdown]
# ```
#
#  97                 for (int i = 0; i < IMAGES_SIZE; i += PIXELS_PER_DATA_PACKAGE) {
# 0000555555557ae7:   movl    $0x0,-0x214(%rbp)
# 0000555555557af1:   mov     -0x214(%rbp),%eax
# 0000555555557af7:   cmp     -0x204(%rbp),%eax
# 0000555555557afd:   jge     0x555555557cbb <main()+1201>
# 100               			dataPackageImage1 = _mm_loadu_ps(&p_compImage1[i]);
# 0000555555557b03:   mov     -0x214(%rbp),%eax
# 0000555555557b09:   cltq
# 0000555555557b0b:   lea     0x0(,%rax,4),%rdx
# 0000555555557b13:   mov     -0x1f8(%rbp),%rax
# 0000555555557b1a:   add     %rdx,%rax
# 0000555555557b1d:   mov     %rax,-0x1d0(%rbp)
#  934                return *(__m128_u *)__P;
# 0000555555557b24:   mov     -0x1d0(%rbp),%rax
# 0000555555557b2b:   vmovups (%rax),%xmm0
# 100               			dataPackageImage1 = _mm_loadu_ps(&p_compImage1[i]);
# 0000555555557b2f:   vmovaps %xmm0,-0x190(%rbp)
# 101               			dataPackageImage2 = _mm_loadu_ps(&p_compImage2[i]);
# 0000555555557b37:   mov     -0x214(%rbp),%eax
# 0000555555557b3d:   cltq
# 0000555555557b3f:   lea     0x0(,%rax,4),%rdx
# 0000555555557b47:   mov     -0x1f0(%rbp),%rax
# 0000555555557b4e:   add     %rdx,%rax
# 0000555555557b51:   mov     %rax,-0x1d8(%rbp)
# 0000555555557b58:   mov     -0x1d8(%rbp),%rax
# 0000555555557b5f:   vmovups (%rax),%xmm0
# 0000555555557b63:   vmovaps %xmm0,-0x180(%rbp)
# 0000555555557b6b:   vmovaps -0x190(%rbp),%xmm0
# 0000555555557b73:   vmovaps %xmm0,-0xd0(%rbp)
# 0000555555557b7b:   vmovaps -0x190(%rbp),%xmm0
# 0000555555557b83:   vmovaps %xmm0,-0xc0(%rbp)
#  198                return (__m128) ((__v4sf)__A * (__v4sf)__B);
# 0000555555557b8b:   vmovaps -0xd0(%rbp),%xmm0
# 0000555555557b93:   vmulps  -0xc0(%rbp),%xmm0,%xmm0
# 104               		squareDP1 = _mm_mul_ps(dataPackageImage1, dataPackageImage1);
# 0000555555557b9b:   vmovaps %xmm0,-0x170(%rbp)
# 0000555555557ba3:   vmovaps -0x180(%rbp),%xmm0
# 0000555555557bab:   vmovaps %xmm0,-0xf0(%rbp)
# 0000555555557bb3:   vmovaps -0x180(%rbp),%xmm0
# 0000555555557bbb:   vmovaps %xmm0,-0xe0(%rbp)
# 0000555555557bc3:   vmovaps -0xf0(%rbp),%xmm0
# 0000555555557bcb:   vmulps  -0xe0(%rbp),%xmm0,%xmm0
# 105               		squareDP2 = _mm_mul_ps(dataPackageImage2, dataPackageImage2);
# 0000555555557bd3:   vmovaps %xmm0,-0x160(%rbp)
# 0000555555557bdb:   vmovaps -0x170(%rbp),%xmm0
# 0000555555557be3:   vmovaps %xmm0,-0x110(%rbp)
# 0000555555557beb:   vmovaps -0x160(%rbp),%xmm0
# 0000555555557bf3:   vmovaps %xmm0,-0x100(%rbp)
#  186                return (__m128) ((__v4sf)__A + (__v4sf)__B);
# 0000555555557bfb:   vmovaps -0x110(%rbp),%xmm0
# 0000555555557c03:   vaddps  -0x100(%rbp),%xmm0,%xmm0
# 108               		productSquareDP1SquareDP2 = _mm_add_ps(squareDP1, squareDP2);
# 0000555555557c0b:   vmovaps %xmm0,-0x150(%rbp)
# 0000555555557c13:   vmovaps -0x150(%rbp),%xmm0
# 0000555555557c1b:   vmovaps %xmm0,-0x120(%rbp)
#  210                return (__m128) __builtin_ia32_sqrtps ((__v4sf)__A);
# 0000555555557c23:   vsqrtps -0x120(%rbp),%xmm0
# 111               			squarerootDPS = _mm_sqrt_ps(productSquareDP1SquareDP2);
# 0000555555557c2b:   vmovaps %xmm0,-0x140(%rbp)
# 0000555555557c33:   vmovaps -0x140(%rbp),%xmm0
# 0000555555557c3b:   vmovaps %xmm0,-0xa0(%rbp)
# 0000555555557c43:   vmovaps -0x1a0(%rbp),%xmm0
# 0000555555557c4b:   vmovaps %xmm0,-0x90(%rbp)
#  204                return (__m128) ((__v4sf)__A / (__v4sf)__B);
# 0000555555557c53:   vmovaps -0xa0(%rbp),%xmm0
# 0000555555557c5b:   vdivps  -0x90(%rbp),%xmm0,%xmm0
# 114               			division = _mm_div_ps(squarerootDPS, V_SQRT2);
# 0000555555557c63:   vmovaps %xmm0,-0x130(%rbp)
# 117               			_mm_storeu_ps(&p_dstImage[i], division);
# 0000555555557c6b:   mov     -0x214(%rbp),%eax
# 0000555555557c71:   cltq
# 0000555555557c73:   lea     0x0(,%rax,4),%rdx
# 0000555555557c7b:   mov     -0x1e8(%rbp),%rax
# 0000555555557c82:   add     %rdx,%rax
# 0000555555557c85:   mov     %rax,-0x1c8(%rbp)
# 0000555555557c8c:   vmovaps -0x130(%rbp),%xmm0
# 0000555555557c94:   vmovaps %xmm0,-0xb0(%rbp)
#  983                *(__m128_u *)__P = __A;
# 0000555555557c9c:   vmovaps -0xb0(%rbp),%xmm0
# 0000555555557ca4:   mov     -0x1c8(%rbp),%rax
# 0000555555557cab:   vmovups %xmm0,(%rax)
#
# ```

# %% [markdown]
# ## Programa overload

# %% [markdown]
# **Tamaño:** 1225240
# **Tiempo individual:** 4.845467 / 80 -> 0,060568

# %% [markdown]
# ```
#
#  97               		for (int i = 0; i < IMAGES_SIZE; i += PIXELS_PER_DATA_PACKAGE) {
# 0000555555557ae7:   movl    $0x0,-0x1c4(%rbp)
# 0000555555557af1:   mov     -0x1c4(%rbp),%eax
# 0000555555557af7:   cmp     -0x1b4(%rbp),%eax
# 0000555555557afd:   jge     0x555555557c6b <main()+1121>
# 127               			dataPackageImage1 = _mm_loadu_ps(&p_compImage1[i]);
# 0000555555557b03:   mov     -0x1c4(%rbp),%eax
# 0000555555557b09:   cltq
# 0000555555557b0b:   lea     0x0(,%rax,4),%rdx
# 0000555555557b13:   mov     -0x1a8(%rbp),%rax
# 0000555555557b1a:   add     %rdx,%rax
# 0000555555557b1d:   mov     %rax,-0x180(%rbp)
#  934                return *(__m128_u *)__P;
# 0000555555557b24:   mov     -0x180(%rbp),%rax
# 0000555555557b2b:   vmovups (%rax),%xmm0
# 127               			dataPackageImage1 = _mm_loadu_ps(&p_compImage1[i]);
# 0000555555557b2f:   vmovaps %xmm0,-0x140(%rbp)
# 128               			dataPackageImage2 = _mm_loadu_ps(&p_compImage2[i]);
# 0000555555557b37:   mov     -0x1c4(%rbp),%eax
# 0000555555557b3d:   cltq
# 0000555555557b3f:   lea     0x0(,%rax,4),%rdx
# 0000555555557b47:   mov     -0x1a0(%rbp),%rax
# 0000555555557b4e:   add     %rdx,%rax
# 0000555555557b51:   mov     %rax,-0x188(%rbp)
#  934                return *(__m128_u *)__P;
# 0000555555557b58:   mov     -0x188(%rbp),%rax
# 0000555555557b5f:   vmovups (%rax),%xmm0
# 0000555555557b63:   vmovaps %xmm0,-0x130(%rbp)
# 0000555555557b6b:   vmovaps -0x130(%rbp),%xmm0
# 0000555555557b73:   vmovaps %xmm0,-0xd0(%rbp)
# 0000555555557b7b:   vmovaps -0x130(%rbp),%xmm0
# 0000555555557b83:   vmovaps %xmm0,-0xc0(%rbp)
#  198                return (__m128) ((__v4sf)__A * (__v4sf)__B);
# 0000555555557b8b:   vmovaps -0xd0(%rbp),%xmm0
# 0000555555557b93:   vmulps  -0xc0(%rbp),%xmm0,%xmm0
# 0000555555557b9b:   vmovaps -0x140(%rbp),%xmm1
# 0000555555557ba3:   vmovaps %xmm1,-0xf0(%rbp)
# 0000555555557bab:   vmovaps -0x140(%rbp),%xmm1
# 0000555555557bb3:   vmovaps %xmm1,-0xe0(%rbp)
# 0000555555557bbb:   vmovaps -0xf0(%rbp),%xmm1
# 0000555555557bc3:   vmulps  -0xe0(%rbp),%xmm1,%xmm1
# 0000555555557bcb:   vmovaps %xmm1,-0x110(%rbp)
# 0000555555557bd3:   vmovaps %xmm0,-0x100(%rbp)
#  186                return (__m128) ((__v4sf)__A + (__v4sf)__B);
# 0000555555557bdb:   vmovaps -0x110(%rbp),%xmm0
# 0000555555557be3:   vaddps  -0x100(%rbp),%xmm0,%xmm0
# 0000555555557beb:   vmovaps %xmm0,-0x120(%rbp)
#  210                return (__m128) __builtin_ia32_sqrtps ((__v4sf)__A);
# 0000555555557bf3:   vsqrtps -0x120(%rbp),%xmm0
# 0000555555557bfb:   vmovaps %xmm0,-0xa0(%rbp)
# 0000555555557c03:   vmovaps -0x150(%rbp),%xmm0
# 0000555555557c0b:   vmovaps %xmm0,-0x90(%rbp)
#  204                return (__m128) ((__v4sf)__A / (__v4sf)__B);
# 0000555555557c13:   vmovaps -0xa0(%rbp),%xmm0
# 0000555555557c1b:   vdivps  -0x90(%rbp),%xmm0,%xmm0
# 131               				&p_dstImage[i],
# 0000555555557c23:   mov     -0x1c4(%rbp),%eax
# 0000555555557c29:   cltq
# 0000555555557c2b:   lea     0x0(,%rax,4),%rdx
# 130               			_mm_storeu_ps(
# 0000555555557c33:   mov     -0x198(%rbp),%rax
# 0000555555557c3a:   add     %rdx,%rax
# 0000555555557c3d:   mov     %rax,-0x178(%rbp)
# 0000555555557c44:   vmovaps %xmm0,-0xb0(%rbp)
#  983                *(__m128_u *)__P = __A;
# 0000555555557c4c:   vmovaps -0xb0(%rbp),%xmm0
# 0000555555557c54:   mov     -0x178(%rbp),%rax
# 0000555555557c5b:   vmovups %xmm0,(%rax)
#
# ```
